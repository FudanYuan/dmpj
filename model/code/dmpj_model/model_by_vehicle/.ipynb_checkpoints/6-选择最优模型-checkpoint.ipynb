# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
vehicle_id = 1
dataset = pd.read_csv('./energy_predict_data/train_data_filter/4_fill_null/whole/filled_by_kmeans/predict_data_e_train_%d.csv' % vehicle_id)
header = dataset.columns.values.tolist()
dataset.describe()
# Out:
#        vehicle_id  charge_start_time  charge_end_time  charge_duration  \
# count       375.0       3.750000e+02     3.750000e+02       375.000000
# mean          1.0       2.017779e+13     2.017782e+13      4216.493333
# std           0.0       4.071652e+09     4.059303e+09      4779.059693
# min           1.0       2.017110e+13     2.017110e+13        60.000000
# 25%           1.0       2.017123e+13     2.017123e+13      1105.000000
# 50%           1.0       2.018013e+13     2.018013e+13      3040.000000
# 75%           1.0       2.018032e+13     2.018032e+13      4768.000000
# max           1.0       2.018061e+13     2.018061e+13     27752.000000
#
#              mileage  delta_mileage  charge_start_soc  charge_end_soc  \
# count     375.000000     375.000000        375.000000      375.000000
# mean   153534.197333      97.333333         31.652267       48.734400
# std      9689.703615     526.865322         25.089969       25.595105
# min    136063.000000       0.000000          0.800000        6.400000
# 25%    146964.000000       0.000000         10.800000       30.400000
# 50%    151847.000000      64.000000         23.600000       33.600000
# 75%    157727.000000      92.500000         51.000000       77.500000
# max    172430.000000    9703.000000         93.000000      100.000000
#
#        charge_delta_soc  charge_start_U  charge_end_U  charge_start_I  \
# count        375.000000      375.000000    375.000000      375.000000
# mean          17.082133      341.666400    368.061867      -34.396533
# std           14.120925       20.953094      8.972666       36.187595
# min            0.000000      255.900000    328.000000     -134.700000
# 25%            4.700000      328.950000    363.750000      -79.650000
# 50%           16.400000      340.300000    372.100000       -9.000000
# 75%           24.000000      358.000000    374.400000       -7.900000
# max           64.000000      374.000000    374.700000       -0.200000
#
#        charge_end_I  charge_max_temp  charge_min_temp  charge_energy
# count    375.000000       375.000000       375.000000     375.000000
# mean     -19.414933        19.917333        11.541333      10.025782
# std       21.848527         8.163509         8.676465       7.377168
# min     -121.600000        -1.000000        -3.000000       0.101000
# 25%      -16.300000        15.000000         6.000000       2.225500
# 50%      -12.700000        19.000000         9.000000      10.492000
# 75%       -7.950000        25.000000        14.000000      15.672000
# max       -0.100000        43.000000        35.000000      33.863341

# %%
sns.distplot(dataset['charge_energy']);
# Out:
# /Users/Jeremy/miniconda3/envs/test/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### 特征选择

# %%
features = header[3:15]
label = header[15]
features, label
# Out:
# (['charge_duration',
#   'mileage',
#   'delta_mileage',
#   'charge_start_soc',
#   'charge_end_soc',
#   'charge_delta_soc',
#   'charge_start_U',
#   'charge_end_U',
#   'charge_start_I',
#   'charge_end_I',
#   'charge_max_temp',
#   'charge_min_temp'],
#  'charge_energy')

# %% [markdown]
# ### 数据标准化

# %%
X = dataset[features]
y = dataset[label]

from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(X.astype(np.float64))

# %% [markdown]
# ### 选择最优模型

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import ShuffleSplit

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR
from sklearn.svm import NuSVR
from sklearn.svm import SVR


estimator_list = [
    LinearRegression(),
    DecisionTreeRegressor(),
    GradientBoostingRegressor(),
    MLPRegressor(solver='lbfgs'),
    AdaBoostRegressor(),
    BaggingRegressor(),
    ExtraTreesRegressor(),
    RandomForestRegressor(),
    LinearSVR(),
    NuSVR(),
    SVR()
]

cv_split = ShuffleSplit(n_splits=6, train_size=0.7, test_size=0.2, random_state=168)
df_columns = ['Name', 'Parameters', 'Train Accuracy Mean', 'Test Accuracy Mean', 'Test Accuracy Std', 'Comsumed Time']
df = pd.DataFrame(columns=df_columns)

row_index = 0
for estimator in estimator_list:
    df.loc[row_index, 'Name'] = estimator.__class__.__name__
    df.loc[row_index, 'Parameters'] = str(estimator.get_params())
    cv_results = cross_validate(estimator, X, y, cv=cv_split)
    df.loc[row_index, 'Train Accuracy Mean'] = cv_results['train_score'].mean()
    df.loc[row_index, 'Test Accuracy Mean'] = cv_results['test_score'].mean()
    df.loc[row_index, 'Test Accuracy Std'] = cv_results['test_score'].std()
    df.loc[row_index, 'Comsumed Time'] = cv_results['fit_time'].mean()
    print(row_index, estimator.__class__.__name__)
    print(cv_results['test_score'])
    row_index += 1
df = df.sort_values(by='Test Accuracy Mean', ascending=False)
df
# Out:
# 0 LinearRegression
# [ 0.92065622  0.94352235  0.85025657  0.85922449  0.93341138  0.95865332]
# 1 DecisionTreeRegressor
# [ 0.89121653  0.94270941  0.90350634  0.89711348  0.88686636  0.89767008]
# 2 GradientBoostingRegressor
# [ 0.95060558  0.95448818  0.92075258  0.91118875  0.95485615  0.98102449]
# 3 MLPRegressor
# [ 0.9336634   0.95250121  0.92673054  0.93079623  0.95374228  0.97881223]
# 4 AdaBoostRegressor
# [ 0.93152378  0.90252524  0.89840253  0.8830394   0.92206156  0.9419843 ]
# 5 BaggingRegressor
# [ 0.93368211  0.95597245  0.91583049  0.90934011  0.94214015  0.97548002]
# 6 ExtraTreesRegressor
# [ 0.9279309   0.96379772  0.91062324  0.93320474  0.94596356  0.98747715]
# 7 RandomForestRegressor
# [ 0.94173544  0.93871644  0.91323623  0.91300528  0.93861821  0.97826266]
# 8 LinearSVR
# [ 0.91753228  0.92927003  0.86558308  0.83435224  0.90514571  0.95258725]
# 9 NuSVR
# [ 0.93974469  0.91250886  0.86828856  0.88835174  0.908893    0.96963715]
# 10 SVR
# [ 0.94286296  0.91856136  0.87084197  0.89152535  0.91290966  0.97111899]
#                          Name  \
# 3                MLPRegressor
# 2   GradientBoostingRegressor
# 6         ExtraTreesRegressor
# 5            BaggingRegressor
# 7       RandomForestRegressor
# 10                        SVR
# 9                       NuSVR
# 4           AdaBoostRegressor
# 0            LinearRegression
# 1       DecisionTreeRegressor
# 8                   LinearSVR
#
#                                            Parameters Train Accuracy Mean  \
# 3   {'activation': 'relu', 'alpha': 0.0001, 'batch...            0.997934
# 2   {'alpha': 0.9, 'criterion': 'friedman_mse', 'i...            0.997279
# 6   {'bootstrap': False, 'criterion': 'mse', 'max_...                   1
# 5   {'base_estimator': None, 'bootstrap': True, 'b...            0.988779
# 7   {'bootstrap': True, 'criterion': 'mse', 'max_d...            0.988973
# 10  {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...            0.937596
# 9   {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...            0.935184
# 4   {'base_estimator': None, 'learning_rate': 1.0,...            0.961043
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...            0.927727
# 1   {'criterion': 'mse', 'max_depth': None, 'max_f...                   1
# 8   {'C': 1.0, 'dual': True, 'epsilon': 0.0, 'fit_...            0.893858
#
#    Test Accuracy Mean Test Accuracy Std Comsumed Time
# 3            0.946041         0.0179513      0.160335
# 2            0.945486         0.0232597     0.0386117
# 6            0.944833         0.0250688     0.0136193
# 5            0.938741         0.0226316     0.0170361
# 7            0.937262         0.0218733      0.018107
# 10            0.91797         0.0326364    0.00369235
# 9            0.914571          0.032995    0.00317458
# 4            0.913256         0.0203527     0.0662907
# 0            0.910954         0.0414216    0.00103331
# 1             0.90318          0.018435    0.00196783
# 8            0.900745         0.0396796    0.00245349

# %% [markdown]
# ### 使用XGBoost

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import ShuffleSplit

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import LinearSVR
from sklearn.svm import NuSVR
from sklearn.svm import SVR
from xgboost import XGBRegressor

estimator_list = [
    LinearRegression(),
    DecisionTreeRegressor(),
    GradientBoostingRegressor(),
    MLPRegressor(solver='lbfgs'),
    AdaBoostRegressor(),
    BaggingRegressor(),
    ExtraTreesRegressor(),
    RandomForestRegressor(),
    LinearSVR(),
    NuSVR(),
    SVR(),
    XGBRegressor()
]

cv_split = ShuffleSplit(n_splits=6, train_size=0.7, test_size=0.2, random_state=168)
df_columns = ['Name', 'Parameters', 'Train Accuracy Mean', 'Test Accuracy Mean', 'Test Accuracy Std', 'Comsumed Time']
df = pd.DataFrame(columns=df_columns)

row_index = 0
for estimator in estimator_list:
    df.loc[row_index, 'Name'] = estimator.__class__.__name__
    df.loc[row_index, 'Parameters'] = str(estimator.get_params())
    cv_results = cross_validate(estimator, X, y, cv=cv_split)
    df.loc[row_index, 'Train Accuracy Mean'] = cv_results['train_score'].mean()
    df.loc[row_index, 'Test Accuracy Mean'] = cv_results['test_score'].mean()
    df.loc[row_index, 'Test Accuracy Std'] = cv_results['test_score'].std()
    df.loc[row_index, 'Comsumed Time'] = cv_results['fit_time'].mean()
    print(row_index, estimator.__class__.__name__)
    print(cv_results['test_score'])
    row_index += 1
df = df.sort_values(by='Test Accuracy Mean', ascending=False)
df
# Out:
# /Users/Jeremy/miniconda3/envs/test/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0 LinearRegression
# [ 0.92065622  0.94352235  0.85025657  0.85922449  0.93341138  0.95865332]
# 1 DecisionTreeRegressor
# [ 0.89124499  0.94131885  0.89952039  0.88148001  0.91008286  0.93786245]
# 2 GradientBoostingRegressor
# [ 0.95362806  0.95439931  0.92058086  0.91123493  0.9539645   0.98097786]
# 3 MLPRegressor
# [ 0.93903039  0.95048679  0.92784538  0.93019152  0.94504535  0.96787023]
# 4 AdaBoostRegressor
# [ 0.94063812  0.91930863  0.90519949  0.88340108  0.92119754  0.93942052]
# 5 BaggingRegressor
# [ 0.94279827  0.95561576  0.9129291   0.91744137  0.94309772  0.9822792 ]
# 6 ExtraTreesRegressor
# [ 0.93798616  0.95902539  0.91815943  0.90984585  0.96006021  0.98748849]
# 7 RandomForestRegressor
# [ 0.91977408  0.94721596  0.92251377  0.91519157  0.9327823   0.98221114]
# 8 LinearSVR
# [ 0.91725321  0.92914142  0.8655239   0.83447112  0.90542405  0.95267566]
# 9 NuSVR
# [ 0.93974469  0.91250886  0.86828856  0.88835174  0.908893    0.96963715]
# 10 SVR
# [ 0.94286296  0.91856136  0.87084197  0.89152535  0.91290966  0.97111899]
# 11 XGBRegressor
# [ 0.9508676   0.96244853  0.91594554  0.90496674  0.95125116  0.97343731]
#                          Name  \
# 2   GradientBoostingRegressor
# 6         ExtraTreesRegressor
# 3                MLPRegressor
# 11               XGBRegressor
# 5            BaggingRegressor
# 7       RandomForestRegressor
# 4           AdaBoostRegressor
# 10                        SVR
# 9                       NuSVR
# 0            LinearRegression
# 1       DecisionTreeRegressor
# 8                   LinearSVR
#
#                                            Parameters Train Accuracy Mean  \
# 2   {'alpha': 0.9, 'criterion': 'friedman_mse', 'i...            0.997279
# 6   {'bootstrap': False, 'criterion': 'mse', 'max_...                   1
# 3   {'activation': 'relu', 'alpha': 0.0001, 'batch...             0.99788
# 11  {'base_score': 0.5, 'colsample_bylevel': 1, 'c...            0.995172
# 5   {'base_estimator': None, 'bootstrap': True, 'b...            0.989796
# 7   {'bootstrap': True, 'criterion': 'mse', 'max_d...            0.988722
# 4   {'base_estimator': None, 'learning_rate': 1.0,...            0.962102
# 10  {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...            0.937596
# 9   {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...            0.935184
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...            0.927727
# 1   {'criterion': 'mse', 'max_depth': None, 'max_f...                   1
# 8   {'C': 1.0, 'dual': True, 'epsilon': 0.0, 'fit_...             0.89366
#
#    Test Accuracy Mean Test Accuracy Std Comsumed Time
# 2            0.945798         0.0233457     0.0425682
# 6            0.945428         0.0265616     0.0140427
# 3            0.943412         0.0134612      0.163431
# 11           0.943153          0.024539     0.0208602
# 5             0.94236         0.0232992     0.0168076
# 7            0.936615         0.0229038     0.0245707
# 4            0.918194         0.0197652     0.0886575
# 10            0.91797         0.0326364    0.00347896
# 9            0.914571          0.032995    0.00398771
# 0            0.910954         0.0414216   0.000767628
# 1            0.910252         0.0224788    0.00192908
# 8            0.900748         0.0396449    0.00282065

# %% [markdown]
# ### 搜索模型最优参数

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
import numpy as np 
import time

xgb_model = XGBRegressor(nthread = 2)
cv_split = ShuffleSplit(n_splits=6, train_size=0.7, test_size=0.2)
param_grid = dict(
    max_depth = [4, 5, 6, 7],
    learning_rate = np.linspace(0.03, 0.3, 10),
    n_estimators = [100, 200]
)
start = time.time()
grid = GridSearchCV(xgb_model, param_grid, cv=cv_split, scoring='neg_mean_squared_error')
grid.fit(X, y)
print('GridSearchCV process use %.2f seconds'%(time.time()-start))

# %%
print(grid.best_params_)
print(grid.best_score_)
print(len(grid._get_param_iterator()))
# Out:
# {'learning_rate': 0.12000000000000001, 'max_depth': 4, 'n_estimators': 200}
# -1.19404176373
# 80
