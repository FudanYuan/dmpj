# %% [markdown]
# ## 新能源电动汽车动力电池充电能量预测（七）——误差分析

# %%
import pandas as pd 
from sklearn import metrics
import numpy as np
from package import utils

# %% [markdown]
# ### 定义数据处理的类型：1.with_fill（使用填充数据）；2.without_fill（不使用填充数据）

# %%
type = 1

# %% [markdown]
# ### 加载真实数据集

# %%
# 导入真实数据集
dataset_real = pd.read_csv('./energy_predict_data/data_prehandle/5_data_split/test/test_%s.csv' % utils.getType(type))
# 数据集大小
count = (int)(np.max(dataset_real['vehicle_id']))
# 数据描述
pd.set_option('precision', 2)
dataset_real.describe()
# Out:
#        vehicle_id  charge_start_time  charge_end_time  charge_duration  \
# count     1506.00           1.51e+03         1.51e+03          1506.00
# mean        11.37           2.02e+13         2.02e+13          7261.55
# std          6.45           1.22e+09         1.22e+09          8210.35
# min          1.00           2.02e+13         2.02e+13           600.00
# 25%          5.00           2.02e+13         2.02e+13          2160.00
# 50%         11.00           2.02e+13         2.02e+13          3843.50
# 75%         17.00           2.02e+13         2.02e+13          8391.00
# max         21.00           2.02e+13         2.02e+13         44535.00
#
#          mileage  delta_mileage  charge_start_soc  charge_end_soc  \
# count    1506.00        1506.00           1506.00         1506.00
# mean   118952.06         100.59             38.66           80.04
# std     29011.07          62.40             19.08           20.75
# min     75285.20           0.00              1.00           11.00
# 25%     93429.15          63.30             23.00           72.76
# 50%    114175.00          93.00             36.00           86.00
# 75%    136668.00         130.75             52.00           98.00
# max    182536.00         441.40             93.00          110.49
#
#        charge_delta_soc  charge_start_U  charge_end_U  charge_start_I  \
# count           1506.00         1506.00       1503.00         1506.00
# mean              41.38          406.52        434.21          -43.31
# std               21.40           89.76         86.91           48.46
# min                0.00          277.80          0.00         -202.00
# 25%               24.00          342.20        374.60          -54.08
# 50%               40.00          361.80        388.30          -24.00
# 75%               60.52          533.60        548.00           -9.00
# max               95.00          571.00        601.40           -0.10
#
#        charge_end_I  charge_max_temp  charge_min_temp  charge_delta_temp  \
# count       1503.00          1506.00          1506.00            1506.00
# mean         -21.05            33.95            22.49              11.48
# std           34.05             9.46            11.84              11.75
# min         -300.00             3.00            -2.00               0.00
# 25%          -18.40            30.00            15.00               6.00
# 50%           -8.50            35.00            26.00               8.00
# 75%           -5.00            40.00            31.00              10.00
# max            3.90            52.00            46.00              51.00
#
#        charge_energy
# count        1506.00
# mean           25.30
# std            21.92
# min             0.42
# 25%            11.65
# 50%            18.86
# 75%            28.27
# max           101.30

# %% [markdown]
# ### 加载预测数据集

# %%
dataset_pred = pd.read_csv('./energy_predict_data/predict_result/data_pred_%s.csv' % utils.getType(type))
# 数据描述
pd.set_option('precision', 2)
dataset_pred.describe()
# Out:
#             id    type       lr   svr_lr  svr_rbf      dtr      rtr      etr  \
# count  1506.00  1506.0  1506.00  1506.00  1506.00  1506.00  1506.00  1506.00
# mean    752.50     1.0    24.82    24.08    23.88    25.28    25.51    25.73
# std     434.89     0.0    21.83    19.08    17.61    21.92    21.79    21.93
# min       0.00     1.0   -15.19    -7.84    -1.49     0.22     0.37     0.47
# 25%     376.25     1.0    10.59    11.60    12.21    11.51    12.38    11.98
# 50%     752.50     1.0    19.67    18.70    18.40    18.71    18.97    19.15
# 75%    1128.75     1.0    32.85    30.21    29.27    28.93    28.61    29.03
# max    1505.00     1.0    84.08    77.73    74.17   102.17   101.98   100.62
#
#            abr       br      gbr     xgbr     mlpr
# count  1506.00  1506.00  1506.00  1506.00  1506.00
# mean     26.90    25.56    25.36    25.37    25.30
# std      20.21    21.87    21.69    21.76    21.44
# min       8.39     0.37    -0.24    -0.12    -1.62
# 25%      14.69    12.33    12.09    12.06    12.30
# 50%      18.70    19.05    18.86    18.71    18.16
# 75%      28.37    28.68    28.16    28.17    27.84
# max      91.68   102.19   100.17   101.33   105.18

# %% [markdown]
# ### 算法列表

# %%
list_columns = dataset_pred.columns.tolist()[2:]
list_columns
# Out:
# ['lr',
#  'svr_lr',
#  'svr_rbf',
#  'dtr',
#  'rtr',
#  'etr',
#  'abr',
#  'br',
#  'gbr',
#  'xgbr',
#  'mlpr']

# %% [markdown]
# ### 获取各算法下的误差并保存

# %%
score = utils.getScore(dataset_real['charge_energy'], dataset_pred, list_columns)
score.to_csv('./energy_predict_data/predict_result/model_score_%s.csv' % utils.getType(type), index = True)
# Out:
# MSE: 64.532006063
# RMSE: 64.532006063
# MAE: 5.78186375679
# RANK: 116.549278003
# ACC: 0.188281824674
# R2: 0.865641044566
# MSE: 67.4054294306
# RMSE: 67.4054294306
# MAE: 4.99671651458
# RANK: 57.2397015492
# ACC: 0.535918897896
# R2: 0.859658429338
# MSE: 68.2254235154
# RMSE: 68.2254235154
# MAE: 4.58624906077
# RANK: 21.9879876493
# ACC: 0.738878245514
# R2: 0.857951159482
# MSE: 9.59316493438
# RMSE: 9.59316493438
# MAE: 1.43003672089
# RANK: 10.2936696883
# ACC: 0.901365937249
# R2: 0.980026537241
# MSE: 6.06226942422
# RMSE: 6.06226942422
# MAE: 1.25513200998
# RANK: 9.76062421206
# ACC: 0.909792253791
# R2: 0.987378043283
# MSE: 6.58024813636
# RMSE: 6.58024813636
# MAE: 1.28966232234
# RANK: 9.89999458235
# ACC: 0.910712157022
# R2: 0.986299584965
# MSE: 26.4678043939
# RMSE: 26.4678043939
# MAE: 4.18732855074
# RANK: 79.1547624794
# ACC: 0.389636113504
# R2: 0.944892670041
# MSE: 6.90368095993
# RMSE: 6.90368095993
# MAE: 1.28510724239
# RANK: 10.0358395361
# ACC: 0.909687648143
# R2: 0.985626181193
# MSE: 6.41101251653
# RMSE: 6.41101251653
# MAE: 1.60034831224
# RANK: 10.8192131227
# ACC: 0.882845435115
# R2: 0.986651942229
# MSE: 6.08868642419
# RMSE: 6.08868642419
# MAE: 1.57826234606
# RANK: 10.5951063809
# ACC: 0.885325901755
# R2: 0.98732304173
# MSE: 8.38378026931
# RMSE: 8.38378026931
# MAE: 2.13414495155
# RANK: 14.0510370551
# ACC: 0.837912768853
# R2: 0.982544538311

# %% [markdown]
# ### 获取每辆车在各算法下的误差

# %%
for id in range(1, co)
score = utils.getScore(dataset_real['charge_energy'], dataset_pred, list_columns)
score.to_csv('./energy_predict_data/predict_result/model_score_%s.csv' % utils.getType(type), index = True)
